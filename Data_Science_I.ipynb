# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielaArvelo/Curso_Data_Science_I/blob/main/Data_Science_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Clase 1**

# %%
print ("Hello world!!")
# Out:
# Hello world!!

# %% [markdown]
# Santa Trinidad de Python Data:
# - Pandas -> Herramienta para dataframes y manipulación de datos
# - metaplotlib -> Herramienta de VIZ
# - Sckit learn -> framework para data science

# %%
x =['EDA','Data Wrangling','Limpieza de datos','SQL','Est. Inferencial', 'ML','DL','IA']
y =[5, 10, 15, 20, 30, 25, 31, 30, 20]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe = pd.DataFrame ({'conocimientos_previos':x, 'q_alumnos':y})
dataframe
# Out:
#   conocimientos_previos  q_alumnos
# 0                   EDA          5
# 1        Data Wrangling         10
# 2         Mineria Datos         15
# 3     Limpieza de datos         20
# 4                   SQL         30
# 5      Est. Inferencial         25
# 6                    ML         31
# 7                    DL         30
# 8                    IA         20

# %%
plt.figure(figsize=(16,9))
sns.set_style("darkgrid")
ax = sns.barplot(x="conocimientos_previos", y="q_alumnos", data=dataframe)
plt.title('Importancia de Habilidades en Data Science', fontsize=16)
plt.xlabel('Cantidad de alumnos con el conocimiento de:', fontsize=12)
plt.ylabel('Nivel de importancia:', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

#Añadir etiquetas de valor a cada barra:
for i, v in enumerate(dataframe['q_alumnos']):
    ax.text(i, v + 0.5, str(v), ha='center', fontsize=10)

plt.show()
